# %%
a=input()
# Out:
#  fkljkd

# %%
b=a[0]

# %%
print (b)
# Out:
# f

# %%
b.upper()
# Out:
# 'F'

# %%
def first_upper(text):
    return text[0].upper() + text[1:]

# %%
my_input = input('Input your text')
first_upper(my_input)
# Out:
# Input your text
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 my_input = input('Input your text')
# ----> 2 first_upper(my_input)
#
# Cell In[21], line 2, in first_upper(text)
#       1 def first_upper(text):
# ----> 2     return text[0].upper() + text[1:]
#
# IndexError: string index out of range

# %%
print(3+3)
# Out:
# 6

# %%
print('3'+'3')
# Out:
# 33

# %%
print(3+int('3b'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(3+int('3b'))
#
# ValueError: invalid literal for int() with base 10: '3b'
